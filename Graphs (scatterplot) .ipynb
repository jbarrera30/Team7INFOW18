# %%
# import the data
import pandas as pd
import matplotlib.pyplot as plt

pd.options.display.float_format = '{:,.2f}'.format
# %matplotlib inline

df = pd.read_csv('/Users/zbelzheng/Team7INFOW18_copy/Crimes_-_2001_to_Present.csv')

cbdf = pd.read_csv('/Users/zbelzheng/Team7INFOW18/chibulls_rawyearstats - sportsref_download (1).csv')
# Out:
# /Users/zbelzheng/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (21) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print(df.shape)
# Out:
# (7165841, 22)

# %%
print(cbdf.shape)
# Out:
# (54, 19)

# %%
df.columns
# Out:
# Index(['ID', 'Case Number', 'Date', 'Block', 'IUCR', 'Primary Type',
#        'Description', 'Location Description', 'Arrest', 'Domestic', 'Beat',
#        'District', 'Ward', 'Community Area', 'FBI Code', 'X Coordinate',
#        'Y Coordinate', 'Year', 'Updated On', 'Latitude', 'Longitude',
#        'Location'],
#       dtype='object')

# %%
df.head()
# Out:
#          ID Case Number                    Date                 Block  IUCR  \
# 0  11034701    JA366925  01/01/2001 11:00:00 AM       016XX E 86TH PL  1153
# 1  11227287    JB147188  10/08/2017 03:00:00 AM    092XX S RACINE AVE  0281
# 2  11227583    JB147595  03/28/2017 02:00:00 PM       026XX W 79TH ST  0620
# 3  11227293    JB147230  09/09/2017 08:17:00 PM  060XX S EBERHART AVE  0810
# 4  11227634    JB147599  08/26/2017 10:00:00 AM   001XX W RANDOLPH ST  0281
#
#           Primary Type                          Description  \
# 0   DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300
# 1  CRIM SEXUAL ASSAULT                       NON-AGGRAVATED
# 2             BURGLARY                       UNLAWFUL ENTRY
# 3                THEFT                            OVER $500
# 4  CRIM SEXUAL ASSAULT                       NON-AGGRAVATED
#
#   Location Description  Arrest  Domestic  ...  Ward  Community Area  FBI Code  \
# 0            RESIDENCE   False     False  ...  8.00           45.00        11
# 1            RESIDENCE   False     False  ... 21.00           73.00        02
# 2                OTHER   False     False  ... 18.00           70.00        05
# 3            RESIDENCE   False     False  ... 20.00           42.00        06
# 4          HOTEL/MOTEL   False     False  ... 42.00           32.00        02
#
#    X Coordinate Y Coordinate  Year              Updated On  Latitude  \
# 0           nan          nan  2001  08/05/2017 03:50:08 PM       nan
# 1           nan          nan  2017  02/11/2018 03:57:41 PM       nan
# 2           nan          nan  2017  02/11/2018 03:57:41 PM       nan
# 3           nan          nan  2017  02/11/2018 03:57:41 PM       nan
# 4           nan          nan  2017  02/11/2018 03:57:41 PM       nan
#
#   Longitude  Location
# 0       nan       NaN
# 1       nan       NaN
# 2       nan       NaN
# 3       nan       NaN
# 4       nan       NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# # Yearly Crimes Exploration

# %%
crime_series = df.groupby(["Year"]).size()
crime_df = crime_series.to_frame()
crime_df
# Out:
#            0
# Year
# 2001  485779
# 2002  486762
# 2003  475960
# 2004  469395
# 2005  453731
# 2006  448136
# 2007  437039
# 2008  427095
# 2009  392762
# 2010  370393
# 2011  351870
# 2012  336124
# 2013  307271
# 2014  275517
# 2015  264422
# 2016  269380
# 2017  268621
# 2018  268115
# 2019  259640
# 2020  117829

# %% [markdown]
# The cell above makes an aggregation of cases per year in chronological order.

# %%
df["Year"].value_counts()

# %% [markdown]
# This cell above sorts the number of cases per year in descending order so the data is not in chronological order anymore.

# %%
df["Year"].min()

# %% [markdown]
# This is to be expected since the minimum value in the Year column would be 2001.

# %%
df["Year"].max()

# %% [markdown]
# This is also to be expected since the maximum value in the Year column would be 2020.

# %%
df["Year"].count()

# %% [markdown]
# This is to be expected since this value matches the 7165841 you get when you do print(df.shape).

# %%
df.groupby(["Year"]).count()
# Out:
#           ID  Case Number    Date   Block    IUCR  Primary Type  Description  \
# Year
# 2001  485779       485779  485779  485779  485779        485779       485779
# 2002  486762       486762  486762  486762  486762        486762       486762
# 2003  475960       475960  475960  475960  475960        475960       475960
# 2004  469395       469395  469395  469395  469395        469395       469395
# 2005  453731       453731  453731  453731  453731        453731       453731
# 2006  448136       448136  448136  448136  448136        448136       448136
# 2007  437039       437039  437039  437039  437039        437039       437039
# 2008  427095       427095  427095  427095  427095        427095       427095
# 2009  392762       392760  392762  392762  392762        392762       392762
# 2010  370393       370392  370393  370393  370393        370393       370393
# 2011  351870       351870  351870  351870  351870        351870       351870
# 2012  336124       336123  336124  336124  336124        336124       336124
# 2013  307271       307271  307271  307271  307271        307271       307271
# 2014  275517       275517  275517  275517  275517        275517       275517
# 2015  264422       264422  264422  264422  264422        264422       264422
# 2016  269380       269380  269380  269380  269380        269380       269380
# 2017  268621       268621  268621  268621  268621        268621       268621
# 2018  268115       268115  268115  268115  268115        268115       268115
# 2019  259640       259640  259640  259640  259640        259640       259640
# 2020  117829       117829  117829  117829  117829        117829       117829
#
#       Location Description  Arrest  Domestic  ...  District    Ward  \
# Year                                          ...
# 2001                485775  485779    485779  ...    485779    4189
# 2002                486757  486762    486762  ...    486762  353650
# 2003                475956  475960    475960  ...    475960  475941
# 2004                469381  469395    469395  ...    469393  469373
# 2005                453717  453731    453731  ...    453730  453730
# 2006                448122  448136    448136  ...    448135  448133
# 2007                437026  437039    437039  ...    437037  437034
# 2008                427063  427095    427095  ...    427055  427091
# 2009                392718  392762    392762  ...    392762  392759
# 2010                370334  370393    370393  ...    370393  370375
# 2011                351579  351870    351870  ...    351870  351856
# 2012                335685  336124    336124  ...    336124  336117
# 2013                307086  307271    307271  ...    307271  307268
# 2014                275173  275517    275517  ...    275517  275515
# 2015                263894  264422    264422  ...    264422  264420
# 2016                268182  269380    269380  ...    269380  269380
# 2017                267414  268621    268621  ...    268620  268620
# 2018                267132  268115    268115  ...    268115  268111
# 2019                258551  259640    259640  ...    259640  259625
# 2020                117235  117829    117829  ...    117829  117825
#
#       Community Area  FBI Code  X Coordinate  Y Coordinate  Updated On  \
# Year
# 2001            6168    485779        482877        482877      485779
# 2002          354123    486762        471528        471528      486762
# 2003          475912    475960        472039        472039      475960
# 2004          469329    469395        467200        467200      469395
# 2005          453677    453731        449920        449920      453731
# 2006          448087    448136        445547        445547      448136
# 2007          436881    437039        435691        435691      437039
# 2008          426852    427095        420028        420028      427095
# 2009          392543    392762        386047        386047      392762
# 2010          370207    370393        370001        370001      370393
# 2011          351689    351870        351306        351306      351870
# 2012          336098    336124        335445        335445      336124
# 2013          307267    307271        306356        306356      307271
# 2014          275517    275517        273722        273722      275517
# 2015          264422    264422        257898        257898      264422
# 2016          269380    269380        267229        267229      269380
# 2017          268621    268621        264926        264926      268621
# 2018          268115    268115        263437        263437      268115
# 2019          259640    259640        258445        258445      259640
# 2020          117829    117829        116904        116904      117829
#
#       Latitude  Longitude  Location
# Year
# 2001    482877     482877    482877
# 2002    471528     471528    471528
# 2003    472039     472039    472039
# 2004    467200     467200    467200
# 2005    449920     449920    449920
# 2006    445547     445547    445547
# 2007    435691     435691    435691
# 2008    420028     420028    420028
# 2009    386047     386047    386047
# 2010    370001     370001    370001
# 2011    351306     351306    351306
# 2012    335445     335445    335445
# 2013    306356     306356    306356
# 2014    273722     273722    273722
# 2015    257898     257898    257898
# 2016    267229     267229    267229
# 2017    264926     264926    264926
# 2018    263437     263437    263437
# 2019    258445     258445    258445
# 2020    116904     116904    116904
#
# [20 rows x 21 columns]

# %% [markdown]
# This looks correct. Most fields have an entry and are aggregated to the total number of cases valid in that year.

# %% [markdown]
# # Looking at crimes where an arrest occurred

# %%
arrested_query = df.query("Arrest == True")
arrested_series = arrested_query.groupby(["Year"]).size()
arrested_df = arrested_series.to_frame()
arrested_df
# Out:
#            0
# Year
# 2001  141910
# 2002  141555
# 2003  141577
# 2004  144690
# 2005  140902
# 2006  135394
# 2007  131862
# 2008  109973
# 2009  110784
# 2010  100501
# 2011   96256
# 2012   90610
# 2013   86489
# 2014   79578
# 2015   69970
# 2016   52936
# 2017   52546
# 2018   53678
# 2019   55355
# 2020   19543

# %%
arrested_df.describe()

# %% [markdown]
# ### Now we want to see the % of crimes where arrests occurred...

# %%
df_joined = crime_df.join(arrested_df)
df_joined
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-eaff8e48e011> in <module>
# ----> 1 df_joined = crime_df.join(arrested_df)
#       2 df_joined
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    7207         """
#    7208         return self._join_compat(
# -> 7209             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    7210         )
#    7211
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    7230                 right_index=True,
#    7231                 suffixes=(lsuffix, rsuffix),
# -> 7232                 sort=sort,
#    7233             )
#    7234         else:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      86         validate=validate,
#      87     )
# ---> 88     return op.get_result()
#      89
#      90
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in get_result(self)
#     647
#     648         llabels, rlabels = _items_overlap_with_suffix(
# --> 649             ldata.items, lsuf, rdata.items, rsuf
#     650         )
#     651
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in _items_overlap_with_suffix(left, lsuffix, right, rsuffix)
#    2024         raise ValueError(
#    2025             "columns overlap but no suffix specified: "
# -> 2026             "{rename}".format(rename=to_rename)
#    2027         )
#    2028
#
# ValueError: columns overlap but no suffix specified: RangeIndex(start=0, stop=1, step=1)

# %%
df_merged = crime_df.merge(arrested_df, on="Year")
df_merged = df_merged.rename(columns = { "0_x" : "Total Crimes", "0_y" : "Total Arrests" })
df_merged
# Out:
#       Total Crimes  Total Arrests
# Year
# 2001        485779         141910
# 2002        486762         141555
# 2003        475960         141577
# 2004        469395         144690
# 2005        453731         140902
# 2006        448136         135394
# 2007        437039         131862
# 2008        427095         109973
# 2009        392762         110784
# 2010        370393         100501
# 2011        351870          96256
# 2012        336124          90610
# 2013        307271          86489
# 2014        275517          79578
# 2015        264422          69970
# 2016        269380          52936
# 2017        268621          52546
# 2018        268115          53678
# 2019        259640          55355
# 2020        117829          19543

# %%
df_merged["% of Crimes Resulting in Arrests"] = df_merged["Total Arrests"].divide(df_merged["Total Crimes"])
df_merged
# Out:
#       Total Crimes  Total Arrests  % of Crimes Resulting in Arrests
# Year
# 2001        485779         141910                              0.29
# 2002        486762         141555                              0.29
# 2003        475960         141577                              0.30
# 2004        469395         144690                              0.31
# 2005        453731         140902                              0.31
# 2006        448136         135394                              0.30
# 2007        437039         131862                              0.30
# 2008        427095         109973                              0.26
# 2009        392762         110784                              0.28
# 2010        370393         100501                              0.27
# 2011        351870          96256                              0.27
# 2012        336124          90610                              0.27
# 2013        307271          86489                              0.28
# 2014        275517          79578                              0.29
# 2015        264422          69970                              0.26
# 2016        269380          52936                              0.20
# 2017        268621          52546                              0.20
# 2018        268115          53678                              0.20
# 2019        259640          55355                              0.21
# 2020        117829          19543                              0.17

# %%
df_merged.describe()
# Out:
#        Total Crimes  Total Arrests  % of Crimes Resulting in Arrests
# count         20.00          20.00                             20.00
# mean     358,292.05      97,805.45                              0.26
# std      102,297.06      38,355.96                              0.04
# min      117,829.00      19,543.00                              0.17
# 25%      269,190.25      66,316.25                              0.25
# 50%      361,131.50      98,378.50                              0.28
# 75%      449,534.75     136,771.00                              0.29
# max      486,762.00     144,690.00                              0.31

# %% [markdown]
# # Chicago Bulls Data

# %%
project_df = cbdf[:20]

# %%
project_df.head()
# Out:
#     Season   Lg            Team   W   L  W/L%    Finish   SRS  Unnamed: 8  \
# 0  2019-20  NBA   Chicago Bulls  22  43  0.34  3rd of 5 -3.85         nan
# 1  2018-19  NBA   Chicago Bulls  22  60  0.27  4th of 5 -8.32         nan
# 2  2017-18  NBA   Chicago Bulls  27  55  0.33  5th of 5 -6.84         nan
# 3  2016-17  NBA  Chicago Bulls*  41  41  0.50  4th of 5  0.03         nan
# 4  2015-16  NBA   Chicago Bulls  42  40  0.51  4th of 5 -1.46         nan
#
#    Pace  Rel Pace   ORtg  Rel ORtg   DRtg  Rel DRtg  Unnamed: 15  \
# 0 99.70     -0.60 106.70     -3.80 109.80     -0.70          nan
# 1 99.00     -1.00 104.80     -5.60 113.20      2.80          nan
# 2 98.30      1.00 103.80     -4.80 110.90      2.30          nan
# 3 95.30     -1.10 107.40     -1.40 107.00     -1.80          nan
# 4 95.70     -0.10 105.00     -1.40 106.50      0.10          nan
#
#                  Playoffs                               Coaches  \
# 0                     NaN                     J. Boylen (22-43)
# 1                     NaN  F. Hoiberg (5-19), J. Boylen (17-41)
# 2                     NaN                    F. Hoiberg (27-55)
# 3  Lost E. Conf. 1st Rnd.                    F. Hoiberg (41-41)
# 4                     NaN                    F. Hoiberg (42-40)
#
#                  Top WS
# 0       Z. LaVine (4.0)
# 1  R. Arcidiacono (3.7)
# 2       B. Portis (3.5)
# 3      J. Butler (13.8)
# 4       J. Butler (9.1)

# %%
project_df.columns
# Out:
# Index(['Season', 'Lg', 'Team', 'W', 'L', 'W/L%', 'Finish', 'SRS', 'Unnamed: 8',
#        'Pace', 'Rel Pace', 'ORtg', 'Rel ORtg', 'DRtg', 'Rel DRtg',
#        'Unnamed: 15', 'Playoffs', 'Coaches', 'Top WS'],
#       dtype='object')

# %% [markdown]
# # W/L% Exploration

# %%
project_df["W/L%"]
# Out:
# 0    0.34
# 1    0.27
# 2    0.33
# 3    0.50
# 4    0.51
# 5    0.61
# 6    0.58
# 7    0.55
# 8    0.76
# 9    0.76
# 10   0.50
# 11   0.50
# 12   0.40
# 13   0.60
# 14   0.50
# 15   0.57
# 16   0.28
# 17   0.37
# 18   0.26
# 19   0.18
# Name: W/L%, dtype: float64

# %%
project_df["W/L%"].value_counts()
# Out:
# 0.50    4
# 0.33    1
# 0.34    1
# 0.28    1
# 0.26    1
# 0.18    1
# 0.76    1
# 0.61    1
# 0.76    1
# 0.57    1
# 0.55    1
# 0.58    1
# 0.40    1
# 0.37    1
# 0.60    1
# 0.51    1
# 0.27    1
# Name: W/L%, dtype: int64

# %%
project_df["W/L%"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0    0.34
# 1    0.27
# 2    0.33
# 3    0.50
# 4    0.51
# 5    0.61
# 6    0.58
# 7    0.55
# 8    0.76
# 9    0.76
# 10   0.50
# 11   0.50
# 12   0.40
# 13   0.60
# 14   0.50
# 15   0.57
# 16   0.28
# 17   0.37
# 18   0.26
# 19   0.18
# Name: W/L%, dtype: float64>

# %%
project_df["W/L%"].max()
# Out:
# 0.758

# %%
project_df["W/L%"].min()
# Out:
# 0.183

# %%
project_df.groupby(["W/L%"]).size()
# Out:
# W/L%
# 0.18    1
# 0.26    1
# 0.27    1
# 0.28    1
# 0.33    1
# 0.34    1
# 0.37    1
# 0.40    1
# 0.50    4
# 0.51    1
# 0.55    1
# 0.57    1
# 0.58    1
# 0.60    1
# 0.61    1
# 0.76    1
# 0.76    1
# dtype: int64

# %%
project_df["W/L%"].describe()
# Out:
# count   20.00
# mean     0.47
# std      0.16
# min      0.18
# 25%      0.34
# 50%      0.50
# 75%      0.58
# max      0.76
# Name: W/L%, dtype: float64

# %% [markdown]
# # Playoff Exploration

# %%
project_df["Playoffs"].value_counts()
# Out:
# Lost E. Conf. 1st Rnd.    7
# Lost E. Conf. Semis       3
# Lost E. Conf. Finals      1
# Name: Playoffs, dtype: int64

# %%
project_df["Playoffs"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0                        NaN
# 1                        NaN
# 2                        NaN
# 3     Lost E. Conf. 1st Rnd.
# 4                        NaN
# 5        Lost E. Conf. Semis
# 6     Lost E. Conf. 1st Rnd.
# 7        Lost E. Conf. Semis
# 8     Lost E. Conf. 1st Rnd.
# 9       Lost E. Conf. Finals
# 10    Lost E. Conf. 1st Rnd.
# 11    Lost E. Conf. 1st Rnd.
# 12                       NaN
# 13       Lost E. Conf. Semis
# 14    Lost E. Conf. 1st Rnd.
# 15    Lost E. Conf. 1st Rnd.
# 16                       NaN
# 17                       NaN
# 18                       NaN
# 19                       NaN
# Name: Playoffs, dtype: object>

# %%
project_df["Playoffs"].describe()
# Out:
# count                         11
# unique                         3
# top       Lost E. Conf. 1st Rnd.
# freq                           7
# Name: Playoffs, dtype: object

# %% [markdown]
# # Coaches Exploration

# %%
project_df["Coaches"].value_counts()
# Out:
# V. Del Negro (41-41)                                       2
# S. Skiles (9-16), P. Myers (0-1), J. Boylan (24-32)        1
# F. Hoiberg (41-41)                                         1
# S. Skiles (49-33)                                          1
# S. Skiles (47-35)                                          1
# T. Thibodeau (50-32)                                       1
# T. Thibodeau (62-20)                                       1
# T. Thibodeau (45-37)                                       1
# T. Thibodeau (50-16)                                       1
# T. Thibodeau (48-34)                                       1
# F. Hoiberg (42-40)                                         1
# F. Hoiberg (5-19), J. Boylen (17-41)                       1
# S. Skiles (41-41)                                          1
# B. Cartwright (30-52)                                      1
# B. Cartwright (4-10), P. Myers (0-2), S. Skiles (19-47)    1
# T. Floyd (4-21), B. Berry (0-2), B. Cartwright (17-38)     1
# J. Boylen (22-43)                                          1
# T. Floyd (15-67)                                           1
# F. Hoiberg (27-55)                                         1
# Name: Coaches, dtype: int64

# %%
project_df["Coaches"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0                                     J. Boylen (22-43)
# 1                  F. Hoiberg (5-19), J. Boylen (17-41)
# 2                                    F. Hoiberg (27-55)
# 3                                    F. Hoiberg (41-41)
# 4                                    F. Hoiberg (42-40)
# 5                                  T. Thibodeau (50-32)
# 6                                  T. Thibodeau (48-34)
# 7                                  T. Thibodeau (45-37)
# 8                                  T. Thibodeau (50-16)
# 9                                  T. Thibodeau (62-20)
# 10                                 V. Del Negro (41-41)
# 11                                 V. Del Negro (41-41)
# 12    S. Skiles (9-16), P. Myers (0-1), J. Boylan (2...
# 13                                    S. Skiles (49-33)
# 14                                    S. Skiles (41-41)
# 15                                    S. Skiles (47-35)
# 16    B. Cartwright (4-10), P. Myers (0-2), S. Skile...
# 17                                B. Cartwright (30-52)
# 18    T. Floyd (4-21), B. Berry (0-2), B. Cartwright...
# 19                                     T. Floyd (15-67)
# Name: Coaches, dtype: object>

# %%
project_df["Coaches"].describe()
# Out:
# count                       20
# unique                      19
# top       V. Del Negro (41-41)
# freq                         2
# Name: Coaches, dtype: object

# %% [markdown]
# # Finish in Division Exploration

# %%
project_df["Finish"].value_counts()
# Out:
# 4th of 5    5
# 2nd of 5    5
# 8th of 8    3
# 3rd of 5    3
# 1st of 5    2
# 5th of 5    1
# 6th of 8    1
# Name: Finish, dtype: int64

# %%
project_df["Finish"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0     3rd of 5
# 1     4th of 5
# 2     5th of 5
# 3     4th of 5
# 4     4th of 5
# 5     2nd of 5
# 6     2nd of 5
# 7     2nd of 5
# 8     1st of 5
# 9     1st of 5
# 10    3rd of 5
# 11    2nd of 5
# 12    4th of 5
# 13    3rd of 5
# 14    4th of 5
# 15    2nd of 5
# 16    8th of 8
# 17    6th of 8
# 18    8th of 8
# 19    8th of 8
# Name: Finish, dtype: object>

# %%
project_df["Finish"].max()
# Out:
# '8th of 8'

# %% [markdown]
# The max function is interpreting the 8th of 8 as an integer so even though 8 is the max value, it's actually the inverse. The max value for this column is actually the min aka the worst finish.

# %%
project_df["Finish"].min()
# Out:
# '1st of 5'

# %% [markdown]
# The min function is interpreting the 1st of 5 as an integer so even though 1 is the min value, it's actually the inverse. The min value for this column is actually the max aka the best finish.

# %% [markdown]
# # Line Graph of Performance Over Time

# %%
reversed_project_df = project_df.iloc[::-1]

reversed_project_df.plot.line(x="Season", y="W/L%", title = "Chicago Bulls Performance Since 2000")
plt.xlabel("Season")
plt.ylabel("Win/Loss %")
# Out:
# Text(0, 0.5, 'Win/Loss %')

# %% [markdown]
# Used .iloc[::-1] in order to reverse the order of the years data because originally it went from present to past and we need it to be past to present.

# %%
project_df_winloss = project_df["W/L%"]
project_df_winloss = project_df_winloss.to_frame()
project_df_winloss = project_df_winloss.iloc[::-1]
winlosslist = project_df_winloss.values.tolist()
new_winlosslist = []
for x in winlosslist:
    for y in x:
        new_winlosslist.append(y)
print(new_winlosslist)
# Out:
# [0.183, 0.256, 0.366, 0.28, 0.573, 0.5, 0.598, 0.402, 0.5, 0.5, 0.7559999999999999, 0.758, 0.5489999999999999, 0.585, 0.61, 0.512, 0.5, 0.32899999999999996, 0.268, 0.33799999999999997]

# %% [markdown]
# ### Create new column with new_winlosslist

# %%
df_merged["W/L%"] = new_winlosslist
df_merged
# Out:
#       Total Crimes  Total Arrests  W/L%
# Year
# 2001        485779         141910  0.18
# 2002        486762         141555  0.26
# 2003        475960         141577  0.37
# 2004        469395         144690  0.28
# 2005        453731         140902  0.57
# 2006        448136         135394  0.50
# 2007        437039         131862  0.60
# 2008        427095         109973  0.40
# 2009        392762         110784  0.50
# 2010        370393         100501  0.50
# 2011        351870          96256  0.76
# 2012        336124          90610  0.76
# 2013        307271          86489  0.55
# 2014        275517          79578  0.58
# 2015        264422          69970  0.61
# 2016        269380          52936  0.51
# 2017        268621          52546  0.50
# 2018        268115          53678  0.33
# 2019        259640          55355  0.27
# 2020        117829          19543  0.34

# %% [markdown]
# # GRAPHS

# %%
##Scatterplot Total Crimes vs W/L%
fig, ax = plt.subplots()
ax.scatter(df_merged['Total Crimes'], df_merged['W/L%'])

# %%
##Bar Graph Total Crimes vs W/L%
crime_v_WL = df_merged.plot.bar(x = "Total Crimes", y = 'W/L%')
plt.xlabel('x - Total Crimes')
plt.ylabel('y - W/L%')
# Out:
# Text(0, 0.5, 'y - W/L%')
